# %% [markdown]
# <a href="https://colab.research.google.com/github/JaydaBubel/lab-working-with-api/blob/master/Lab_working_with_api_JaydaB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import requests

url = "https://aerodatabox.p.rapidapi.com/health/services/feeds/FlightSchedules/airports"

headers = {
    'x-rapidapi-host': "aerodatabox.p.rapidapi.com",
    'x-rapidapi-key': "9613ca6ca5msh62659872159916fp1a0a2cjsndd9a3e6ff324"
    }

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"count":3364,"items":["KSAF","PAEN","UUOB","EGLL","KCAK","KITH","LEGE","OEHL","ZBYC","ZSSH","HKKI","KSGF","KTVC","USRK","VYKI","CYKF","CYYJ","LGKJ","PASH","VIPT","WIII","CYZR","FALA","FTTY","KBFF","KMIA","SBVH","WMKN","YMAE","ZGGG","CYFC","KFAT","OISS","SKPD","ENLK","KGLH","LFRZ","NZWB","RJBB","RKTH","SBTC","VOGO","ZYJZ","CYXS","ENGM","EPWR","OIZC","PAPB","ROAH","UKLL","VVPB","BGPT","GVSF","HKMO","SAZS","YFTZ","CCZ2","KDSM","NTTR","PAUK","UNEE","WBKL","ZBTL","EGPN","KBED","KBZN","LFRD","PAKP","SVMC","DTTJ","EDDF","LEJR","MBSY","NFNA","NTTO","PAJZ","SCSE","UUYY","YMTG","AYMS","LTCR","MYGF","SBDB","WBGQ","DIOD","ENFL","KCRW","KJMS","LTDA","MYSM","NTGQ","SBTT","DTNH","ENHV","KCLE","MBGT","OIBL","SBPV","VIJP","YIVL","ZUZH","CAP3","CYSM","MHSC","OEDF","RJKI","RPMH","SECU","YWBS","KSLC","LEMI","LTFE","SKCC","ZLZY","CYWJ","KFLL","LIMF","MDJB","NZCH","PFKU","UAUU","KSNA","LEBZ","LICB","MMPG","PASA","SWTS","VLSK","WIDN","ZHNY","PAWI","RJCC","SWGN","VYTL","CYGW","FAPE","KBJI","KDAL","KYKM","U
# ...

# %%
url = "https://aerodatabox.p.rapidapi.com/airports/search/term"

querystring = {"q":"berlin","limit":"10"}

headers = {
    'x-rapidapi-host': "aerodatabox.p.rapidapi.com",
    'x-rapidapi-key': "9613ca6ca5msh62659872159916fp1a0a2cjsndd9a3e6ff324"
    }

response = requests.get(url, headers=headers, params=querystring)

result = response.json()
result
# Out:
# {'searchBy': 'berlin',
#  'count': 3,
#  'items': [{'icao': 'EDDB',
#    'iata': 'BER',
#    'name': 'Berlin Brandenburg',
#    'shortName': 'Brandenburg',
#    'municipalityName': 'Berlin',
#    'location': {'lat': 52.35139, 'lon': 13.493889},
#    'countryCode': 'DE'},
#   {'icao': 'EDDT',
#    'iata': 'TXL',
#    'name': 'Berlin -Tegel',
#    'shortName': '-Tegel',
#    'municipalityName': 'Berlin',
#    'location': {'lat': 52.5597, 'lon': 13.287699},
#    'countryCode': 'DE'},
#   {'icao': 'KBML',
#    'iata': 'BML',
#    'name': 'Berlin Regional',
#    'shortName': 'Regional',
#    'municipalityName': 'Berlin',
#    'location': {'lat': 44.5754, 'lon': -71.1759},
#    'countryCode': 'US'}]}

# %%
result["items"][0]["countryCode"]
# Out:
# 'DE'

# %%
result['items']
# Out:
# [{'icao': 'EDDB',
#   'iata': 'BER',
#   'name': 'Berlin Brandenburg',
#   'shortName': 'Brandenburg',
#   'municipalityName': 'Berlin',
#   'location': {'lat': 52.35139, 'lon': 13.493889},
#   'countryCode': 'DE'},
#  {'icao': 'EDDT',
#   'iata': 'TXL',
#   'name': 'Berlin -Tegel',
#   'shortName': '-Tegel',
#   'municipalityName': 'Berlin',
#   'location': {'lat': 52.5597, 'lon': 13.287699},
#   'countryCode': 'DE'},
#  {'icao': 'KBML',
#   'iata': 'BML',
#   'name': 'Berlin Regional',
#   'shortName': 'Regional',
#   'municipalityName': 'Berlin',
#   'location': {'lat': 44.5754, 'lon': -71.1759},
#   'countryCode': 'US'}]

# %%
pd.json_normalize(result['items'])
# Out:
#    icao iata                name    shortName municipalityName countryCode  \
# 0  EDDB  BER  Berlin Brandenburg  Brandenburg           Berlin          DE
# 1  EDDT  TXL       Berlin -Tegel       -Tegel           Berlin          DE
# 2  KBML  BML     Berlin Regional     Regional           Berlin          US
#
#    location.lat  location.lon
# 0      52.35139     13.493889
# 1      52.55970     13.287699
# 2      44.57540    -71.175900

# %%
icao_from = 'EDDB'
icao_to = 'EDDT'

url = f"https://aerodatabox.p.rapidapi.com/airports/icao/{icao_from}/distance-time/{icao_to}"

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'from': {'icao': 'EDDB', 'iata': 'BER', 'name': 'Berlin Brandenburg', 'shortName': 'Brandenburg', 'municipalityName': 'Berlin', 'location': {'lat': 52.35139, 'lon': 13.493889}, 'countryCode': 'DE'}, 'to': {'icao': 'EDDT', 'iata': 'TXL', 'name': 'Berlin -Tegel', 'shortName': '-Tegel', 'municipalityName': 'Berlin', 'location': {'lat': 52.5597, 'lon': 13.287699}, 'countryCode': 'DE'}, 'greatCircleDistance': {'meter': 27088.28, 'km': 27.09, 'mile': 16.83, 'nm': 14.63, 'feet': 88872.3}, 'approxFlightTime': '00:20:00'}

# %%
pd.json_normalize(response.json())
# Out:
#   approxFlightTime from.icao from.iata           from.name from.shortName  \
# 0         00:20:00      EDDB       BER  Berlin Brandenburg    Brandenburg
#
#   from.municipalityName  from.location.lat  from.location.lon  \
# 0                Berlin           52.35139          13.493889
#
#   from.countryCode to.icao  ... to.shortName to.municipalityName  \
# 0               DE    EDDT  ...       -Tegel              Berlin
#
#   to.location.lat to.location.lon  to.countryCode  greatCircleDistance.meter  \
# 0         52.5597       13.287699              DE                   27088.28
#
#   greatCircleDistance.km  greatCircleDistance.mile  greatCircleDistance.nm  \
# 0                  27.09                     16.83                   14.63
#
#    greatCircleDistance.feet
# 0                   88872.3
#
# [1 rows x 22 columns]
